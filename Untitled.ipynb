# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
import cv2
# Out:
# Using TensorFlow backend.

# %%
import codecs
batch_size = 64  
epochs = 25  
latent_dim = 256  
num_samples = 10000  
data_path = 'fra.txt'

# %%
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

# %%
with codecs.open(data_path, 'rb', encoding='utf-8',errors='ignore') as f:
    lines = f.read().split('\n')

# %%
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text= line.split('\u202f')[0].split('\t')[0]
    target_text= line.split('\u202f')[0].split('\t')[1]
    
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 71
# Number of unique output tokens: 92
# Max sequence length for inputs: 16
# Max sequence length for outputs: 59

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

# %%
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length, num_encoder_tokens),dtype='float32')
decoder_input_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')
decoder_target_data = np.zeros((len(input_texts), max_decoder_seq_length, num_decoder_tokens),dtype='float32')

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %%
print(encoder_input_data.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)
# Out:
# (10000, 16, 71)
# (10000, 59, 92)
# (10000, 59, 92)

# %%
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)


model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])

model.fit([encoder_input_data, decoder_input_data], decoder_target_data,batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/25
# 8000/8000 [==============================] - 28s 4ms/step - loss: 1.1743 - accuracy: 0.7261 - val_loss: 1.1160 - val_accuracy: 0.7002
# Epoch 2/25
# 8000/8000 [==============================] - 28s 3ms/step - loss: 0.8544 - accuracy: 0.7699 - val_loss: 0.8457 - val_accuracy: 0.7661
# Epoch 3/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.7041 - accuracy: 0.8052 - val_loss: 0.7296 - val_accuracy: 0.7894
# Epoch 4/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.6081 - accuracy: 0.8239 - val_loss: 0.6668 - val_accuracy: 0.8057
# Epoch 5/25
# 8000/8000 [==============================] - 28s 3ms/step - loss: 0.5545 - accuracy: 0.8387 - val_loss: 0.6204 - val_accuracy: 0.8188
# Epoch 6/25
# 8000/8000 [==============================] - 30s 4ms/step - loss: 0.5163 - accuracy: 0.8491 - val_loss: 0.5864 - val_accuracy: 0.8288
# Epoch 7/25
# 8000/8000 [==============================] - 26s 3ms/step - loss: 0.4871 - accuracy: 0.8567 - val_loss: 0.5582 - val_accuracy: 0.8350
# Epoch 8/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.4625 - accuracy: 0.8626 - val_loss: 0.5381 - val_accuracy: 0.8407
# Epoch 9/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.4404 - accuracy: 0.8687 - val_loss: 0.5251 - val_accuracy: 0.8446
# Epoch 10/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.4211 - accuracy: 0.8742 - val_loss: 0.5057 - val_accuracy: 0.8500
# Epoch 11/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.4032 - accuracy: 0.8792 - val_loss: 0.4929 - val_accuracy: 0.8536
# Epoch 12/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3872 - accuracy: 0.8841 - val_loss: 0.4809 - val_accuracy: 0.8570
# Epoch 13/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3722 - accuracy: 0.8882 - val_loss: 0.4740 - val_accuracy: 0.8593
# Epoch 14/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3581 - accuracy: 0.8923 - val_loss: 0.4723 - val_accuracy: 0.8590
# Epoch 15/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3446 - accuracy: 0.8965 - val_loss: 0.4601 - val_accuracy: 0.8624
# Epoch 16/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3318 - accuracy: 0.9000 - val_loss: 0.4504 - val_accuracy: 0.8655
# Epoch 17/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3201 - accuracy: 0.9035 - val_loss: 0.4482 - val_accuracy: 0.8677
# Epoch 18/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.3088 - accuracy: 0.9072 - val_loss: 0.4461 - val_accuracy: 0.8692
# Epoch 19/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.2980 - accuracy: 0.9103 - val_loss: 0.4457 - val_accuracy: 0.8699
# Epoch 20/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.2878 - accuracy: 0.9132 - val_loss: 0.4442 - val_accuracy: 0.8700
# Epoch 21/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.2780 - accuracy: 0.9159 - val_loss: 0.4427 - val_accuracy: 0.8708
# Epoch 22/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.2689 - accuracy: 0.9186 - val_loss: 0.4397 - val_accuracy: 0.8725
# Epoch 23/25
# 8000/8000 [==============================] - 26s 3ms/step - loss: 0.2600 - accuracy: 0.9212 - val_loss: 0.4409 - val_accuracy: 0.8732
# Epoch 24/25
# 8000/8000 [==============================] - 27s 3ms/step - loss: 0.2513 - accuracy: 0.9238 - val_loss: 0.4434 - val_accuracy: 0.8722
# Epoch 25/25
# 8000/8000 [==============================] - 28s 3ms/step - loss: 0.2433 - accuracy: 0.9261 - val_loss: 0.4423 - val_accuracy: 0.8739

# %%
model.save('model-weights.h5')

# %%
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Prends pas !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# -
# Input sentence: Run!
# Decoded sentence: Prends plas fout.
#
# -
# Input sentence: Run!
# Decoded sentence: Prends plas fout.
#
# -
# Input sentence: Who?
# Decoded sentence: Qui est à la maison?
#
# -
# Input sentence: Wow!
# Decoded sentence: Avez-vous donne un coup ?
#
# -
# Input sentence: Fire!
# Decoded sentence: Apprecez-moi !
#
# -
# Input sentence: Help!
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Jump.
# Decoded sentence: Saruitez
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Stop!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# -
# Input sentence: Go on.
# Decoded sentence: Pars !
#
# -
# Input sentence: Go on.
# Decoded sentence: Pars !
#
# -
# Input sentence: Go on.
# Decoded sentence: Pars !
#
# -
# Input sentence: Hello!
# Decoded sentence: Arrez-vous !
#
# -
# Input sentence: Hello!
# Decoded sentence: Arrez-vous !
#
# -
# Input sentence: I see.
# Decoded sentence: Je me suis senti mal.
#
# -
# Input sentence: I try.
# Decoded sentence: J'ai préparé.
#
# -
# Input sentence: I won!
# Decoded sentence: J'ai détendu te pais.
#
# -
# Input sentence: I won!
# Decoded sentence: J'ai détendu te pais.
#
# -
# Input sentence: I won.
# Decoded sentence: Je l'ai en arvé.
#
# -
# Input sentence: Oh no!
# Decoded sentence: Es-tu colète !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attends ça !
#
# -
# Input sentence: Attack!
# Decoded sentence: Attends ça !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Sarchez-vous !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Sarchez-vous !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Sarchez-vous !
#
# -
# Input sentence: Cheers!
# Decoded sentence: Sarchez-vous !
#
# -
# Input sentence: Get up.
# Decoded sentence: Sors du vois prêtes.
#
# -
# Input sentence: Go now.
# Decoded sentence: Poursuis !
#
# -
# Input sentence: Go now.
# Decoded sentence: Poursuis !
#
# -
# Input sentence: Go now.
# Decoded sentence: Poursuis !
#
# -
# Input sentence: Got it!
# Decoded sentence: Allez !
#
# -
# Input sentence: Got it!
# Decoded sentence: Allez !
#
# -
# Input sentence: Got it?
# Decoded sentence: Allez !
#
# -
# Input sentence: Got it?
# Decoded sentence: Allez !
#
# -
# Input sentence: Got it?
# Decoded sentence: Allez !
#
# -
# Input sentence: Hop in.
# Decoded sentence: Cestionsez-vous !
#
# -
# Input sentence: Hop in.
# Decoded sentence: Cestionsez-vous !
#
# -
# Input sentence: Hug me.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Hug me.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: I fell.
# Decoded sentence: Je me sens prépare.
#
# -
# Input sentence: I fell.
# Decoded sentence: Je me sens prépare.
#
# -
# Input sentence: I know.
# Decoded sentence: Je le parais.
#
# -
# Input sentence: I left.
# Decoded sentence: Je me sens prépare.
#
# -
# Input sentence: I left.
# Decoded sentence: Je me sens prépare.
#
# -
# Input sentence: I lied.
# Decoded sentence: Je le parais.
#
# -
# Input sentence: I lost.
# Decoded sentence: Je le suis sentie en sécurité.
#
# -
# Input sentence: I paid.
# Decoded sentence: Je te pas en sempe.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: Je suis partient.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis partient.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Je suis partient.
#
# -
# Input sentence: Listen.
# Decoded sentence: Allons-le-loi.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: No way!
# Decoded sentence: Personne n'est avous.
#
# -
# Input sentence: Really?
# Decoded sentence: Prends-tu ?
#
# -
# Input sentence: Really?
# Decoded sentence: Prends-tu ?
#
# -
# Input sentence: Really?
# Decoded sentence: Prends-tu ?
#
# -
# Input sentence: Thanks.
# Decoded sentence: Marchez-vous !
#
# -
# Input sentence: We try.
# Decoded sentence: Nous avons terminé.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons besoin de la maison.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons besoin de la maison.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons besoin de la maison.
#
# -
# Input sentence: We won.
# Decoded sentence: Nous avons besoin de la maison.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Demandez à n'importe qui.
#
# -
# Input sentence: Awesome!
# Decoded sentence: Laissez-vous parter !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be calm.
# Decoded sentence: Soyez calme !
#
# -
# Input sentence: Be cool.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be fair.
# Decoded sentence: Soyez créatif !
#
# -
# Input sentence: Be kind.
# Decoded sentence: Sois prête !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Be nice.
# Decoded sentence: Soyez discret !
#
# -
# Input sentence: Beat it.
# Decoded sentence: Allez !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Call me.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Call us.
# Decoded sentence: Appelle-moi !
#
# -
# Input sentence: Come in.
# Decoded sentence: Viens à l'écart.
